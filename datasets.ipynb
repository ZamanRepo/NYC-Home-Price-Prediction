# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %% [markdown]
# # 2003 to 2008 NYC Housing Datasets

# %%
df_2003_1 = pd.read_excel('data/NYC_Sales_2003-2020/sales_manhattan_03.xls', header=3)
df_2003_2 = pd.read_excel('data/NYC_Sales_2003-2020/sales_bronx_03.xls', header=3)
df_2003_3 = pd.read_excel('data/NYC_Sales_2003-2020/sales_queens_03.xls', header=3)
df_2003_4 = pd.read_excel('data/NYC_Sales_2003-2020/sales_brooklyn_03.xls', header=3)
df_2003_5 = pd.read_excel('data/NYC_Sales_2003-2020/sales_si_03.xls', header=3)

# %%
df_2003_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22210 entries, 0 to 22209
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         22210 non-null  int64
#  1   NEIGHBORHOOD                    22210 non-null  object
#  2   BUILDING CLASS CATEGORY         22210 non-null  object
#  3   TAX CLASS AT PRESENT            22210 non-null  object
#  4   BLOCK                           22210 non-null  int64
#  5   LOT                             22210 non-null  int64
#  6   EASE-MENT                       22210 non-null  object
#  7   BUILDING CLASS AT PRESENT       22210 non-null  object
#  8   ADDRESS                         22210 non-null  object
#  9   APARTMENT NUMBER                22210 non-null  object
#  10  ZIP CODE                        22210 non-null  int64
#  11  RESIDENTIAL UNITS               22210 non-null  int64
# ...

# %%
df_2003 = pd.concat([df_2003_1, df_2003_2, df_2003_3, df_2003_4, df_2003_5])
df_2003.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  02  TWO FAMILY HOMES                                            1    375
# 1  07  RENTALS - WALKUP APARTMENTS                                2A    372
# 2  07  RENTALS - WALKUP APARTMENTS                                2A    372
# 3  07  RENTALS - WALKUP APARTMENTS                                2B    378
# 4  07  RENTALS - WALKUP APARTMENTS                                 2    391
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   32                                  B9
# 1   31                                  C3
# 2   31                                  C3
# 3   33                                  C4
# 4   12                                  C1
#
# ...

# %%
df_2003.shape
# Out:
# (118428, 21)

# %%
df_2003.to_csv('data/df_2003.csv')

# %%
df_2004_1 = pd.read_excel('data/NYC_Sales_2003-2020/sales_manhattan_04.xls', header=3)
df_2004_2 = pd.read_excel('data/NYC_Sales_2003-2020/sales_bronx_04.xls', header=3)
df_2004_3 = pd.read_excel('data/NYC_Sales_2003-2020/sales_queens_04.xls', header=3)
df_2004_4 = pd.read_excel('data/NYC_Sales_2003-2020/sales_brooklyn_04.xls', header=3)
df_2004_5 = pd.read_excel('data/NYC_Sales_2003-2020/sales_si_04.xls', header=3)

# %%
df_2004_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25894 entries, 0 to 25893
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         25894 non-null  int64
#  1   NEIGHBORHOOD                    25894 non-null  object
#  2   BUILDING CLASS CATEGORY         25894 non-null  object
#  3   TAX CLASS AT PRESENT            25894 non-null  object
#  4   BLOCK                           25894 non-null  int64
#  5   LOT                             25894 non-null  int64
#  6   EASE-MENT                       25894 non-null  object
#  7   BUILDING CLASS AT PRESENT       25894 non-null  object
#  8   ADDRESS                         25894 non-null  object
#  9   APARTMENT NUMBER                25894 non-null  object
#  10  ZIP CODE                        25894 non-null  int64
#  11  RESIDENTIAL UNITS               25894 non-null  int64
# ...

# %%
df_2004 = pd.concat([df_2004_1, df_2004_2, df_2004_3, df_2004_4, df_2004_5])
df_2004.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  02  TWO FAMILY HOMES                                            1    377
# 1  02  TWO FAMILY HOMES                                            1    386
# 2  02  TWO FAMILY HOMES                                            1    386
# 3  02  TWO FAMILY HOMES                                            1    386
# 4  02  TWO FAMILY HOMES                                            1    386
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   70                                  B1
# 1    7                                  S2
# 2    7                                  S2
# 3    8                                  S2
# 4    8                                  S2
#
# ...

# %%
df_2004.shape
# Out:
# (126591, 21)

# %%
df_2004.to_csv('data/df_2004.csv')

# %%
df_2005_1 = pd.read_excel('data/NYC_Sales_2003-2020/sales_manhattan_05.xls', header=3)
df_2005_2 = pd.read_excel('data/NYC_Sales_2003-2020/sales_bronx_05.xls', header=3)
df_2005_3 = pd.read_excel('data/NYC_Sales_2003-2020/sales_queens_05.xls', header=3)
df_2005_4 = pd.read_excel('data/NYC_Sales_2003-2020/sales_brooklyn_05.xls', header=3)
df_2005_5 = pd.read_excel('data/NYC_Sales_2003-2020/sales_si_05.xls', header=3)

# %%
df_2005 = pd.concat([df_2005_1, df_2005_2, df_2005_3, df_2005_4, df_2005_5])
df_2005.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  02  TWO FAMILY HOMES                                            1    390
# 1  02  TWO FAMILY HOMES                                            1    390
# 2  02  TWO FAMILY HOMES                                            1    390
# 3  02  TWO FAMILY HOMES                                            1    391
# 4  03  THREE FAMILY HOMES                                          1    377
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   36                                  S2
# 1   36                                  S2
# 2   36                                  S2
# 3   51                                  B9
# 4   56                                  C0
#
# ...

# %%
df_2005.shape
# Out:
# (123643, 21)

# %%
df_2005.to_csv('data/df_2005.csv')

# %%
df_2006_1 = pd.read_excel('data/NYC_Sales_2003-2020/sales_manhattan_06.xls', header=3)
df_2006_2 = pd.read_excel('data/NYC_Sales_2003-2020/sales_bronx_06.xls', header=3)
df_2006_3 = pd.read_excel('data/NYC_Sales_2003-2020/sales_queens_06.xls', header=3)
df_2006_4 = pd.read_excel('data/NYC_Sales_2003-2020/sales_brooklyn_06.xls', header=3)
df_2006_5 = pd.read_excel('data/NYC_Sales_2003-2020/sales_si_06.xls', header=3)

# %%
df_2006 = pd.concat([df_2006_1, df_2006_2, df_2006_3, df_2006_4, df_2006_5])
df_2006.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1    386
# 1  01  ONE FAMILY HOMES                                            1    402
# 2  02  TWO FAMILY HOMES                                            1    379
# 3  03  THREE FAMILY HOMES                                          1    377
# 4  07  RENTALS - WALKUP APARTMENTS                                2B    376
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   61                                  A9
# 1   42                                  S1
# 2    9                                  A4
# 3   56                                  C0
# 4   39                                  C7
#
# ...

# %%
df_2006.shape
# Out:
# (115472, 21)

# %%
df_2006.to_csv('data/df_2006.csv')

# %%
df_2007_1 = pd.read_excel('data/NYC_Sales_2003-2020/sales_2007_manhattan.xls', header=3)
df_2007_2 = pd.read_excel('data/NYC_Sales_2003-2020/sales_2007_bronx.xls', header=3)
df_2007_3 = pd.read_excel('data/NYC_Sales_2003-2020/sales_2007_queens.xls', header=3)
df_2007_4 = pd.read_excel('data/NYC_Sales_2003-2020/sales_2007_brooklyn.xls', header=3)
df_2007_5 = pd.read_excel('data/NYC_Sales_2003-2020/sales_2007_statenisland.xls', header=3)

# %%
df_2007 = pd.concat([df_2007_1, df_2007_2, df_2007_3, df_2007_4, df_2007_5])
df_2007.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  02  TWO FAMILY HOMES                                                 406
# 1  07  RENTALS - WALKUP APARTMENTS                                2B    384
# 2  07  RENTALS - WALKUP APARTMENTS                                2B    384
# 3  07  RENTALS - WALKUP APARTMENTS                                 2    387
# 4  07  RENTALS - WALKUP APARTMENTS                                2B    396
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   52
# 1   17                                  C4
# 2   18                                  C4
# 3  157                                  C1
# 4    3                                  C4
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# ...

# %%
df_2007.shape
# Out:
# (107009, 21)

# %%
df_2007.to_csv('data/df_2007.csv')

# %%
df_2008_1 = pd.read_excel('data/NYC_Sales_2003-2020/sales_2008_manhattan.xls', header=3)
df_2008_2 = pd.read_excel('data/NYC_Sales_2003-2020/sales_2008_bronx.xls', header=3)
df_2008_3 = pd.read_excel('data/NYC_Sales_2003-2020/sales_2008_queens.xls', header=3)
df_2008_4 = pd.read_excel('data/NYC_Sales_2003-2020/sales_2008_brooklyn.xls', header=3)
df_2008_5 = pd.read_excel('data/NYC_Sales_2003-2020/sales_2008_statenisland.xls', header=3)

# %%
df_2008 = pd.concat([df_2008_1, df_2008_2, df_2008_3, df_2008_4, df_2008_5])
df_2008.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1    402
# 1  01  ONE FAMILY HOMES                                            1    402
# 2  01  ONE FAMILY HOMES                                            1    402
# 3  03  THREE FAMILY HOMES                                          1    377
# 4  03  THREE FAMILY HOMES                                          1    389
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   42                                  S1
# 1   42                                  S1
# 2   42                                  S1
# 3   66                                  C0
# 4   29                                  A5
#
# ...

# %%
df_2008.shape
# Out:
# (91147, 21)

# %%
df_2008.to_csv('data/df_2008.csv')

# %%
df_2003_08 = pd.concat([df_2003, df_2004, df_2005, df_2006, df_2007, df_2008])
df_2003_08.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  02  TWO FAMILY HOMES                                            1    375
# 1  07  RENTALS - WALKUP APARTMENTS                                2A    372
# 2  07  RENTALS - WALKUP APARTMENTS                                2A    372
# 3  07  RENTALS - WALKUP APARTMENTS                                2B    378
# 4  07  RENTALS - WALKUP APARTMENTS                                 2    391
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   32                                  B9
# 1   31                                  C3
# 2   31                                  C3
# 3   33                                  C4
# 4   12                                  C1
#
# ...

# %%
df_2003_08.shape
# Out:
# (682290, 21)

# %%
df_2003_08.to_csv('data/df_2003_08.csv')

# %% [markdown]
# # 2009 to 2015 NYC Housing Dataset

# %%
df_2009_1 = pd.read_excel('data/NYC_Sales_2003-2020/2009_manhattan.xls', header=3)
df_2009_2 = pd.read_excel('data/NYC_Sales_2003-2020/2009_bronx.xls', header=3)
df_2009_3 = pd.read_excel('data/NYC_Sales_2003-2020/2009_queens.xls', header=3)
df_2009_4 = pd.read_excel('data/NYC_Sales_2003-2020/2009_brooklyn.xls', header=3)
df_2009_5 = pd.read_excel('data/NYC_Sales_2003-2020/2009_statenisland.xls', header=3)

# %%
df_2009_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19166 entries, 0 to 19165
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         19166 non-null  int64
#  1   NEIGHBORHOOD                    19166 non-null  object
#  2   BUILDING CLASS CATEGORY         19166 non-null  object
#  3   TAX CLASS AT PRESENT            19166 non-null  object
#  4   BLOCK                           19166 non-null  int64
#  5   LOT                             19166 non-null  int64
#  6   EASE-MENT                       19166 non-null  object
#  7   BUILDING CLASS AT PRESENT       19166 non-null  object
#  8   ADDRESS                         19166 non-null  object
#  9   APARTMENT NUMBER                19166 non-null  object
#  10  ZIP CODE                        19166 non-null  int64
#  11  RESIDENTIAL UNITS               19166 non-null  int64
# ...

# %%
df_2009 = pd.concat([df_2009_1, df_2009_2, df_2009_3, df_2009_4, df_2009_5])
df_2009.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07  RENTALS - WALKUP APARTMENTS                                2B    372
# 1  07  RENTALS - WALKUP APARTMENTS                                2A    377
# 2  07  RENTALS - WALKUP APARTMENTS                                 2    385
# 3  07  RENTALS - WALKUP APARTMENTS                                2B    386
# 4  07  RENTALS - WALKUP APARTMENTS                                 2    400
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   19                                  C7
# 1   53                                  C2
# 2   53                                  C4
# 3   63                                  D7
# 4   53                                  C1
#
# ...

# %%
df_2009.to_csv('data/df_2009.csv')

# %%
df_2010_1 = pd.read_excel('data/NYC_Sales_2003-2020/2010_manhattan.xls', header=3)
df_2010_2 = pd.read_excel('data/NYC_Sales_2003-2020/2010_bronx.xls', header=3)
df_2010_3 = pd.read_excel('data/NYC_Sales_2003-2020/2010_queens.xls', header=3)
df_2010_4 = pd.read_excel('data/NYC_Sales_2003-2020/2010_brooklyn.xls', header=3)
df_2010_5 = pd.read_excel('data/NYC_Sales_2003-2020/2010_statenisland.xls', header=3)

# %%
df_2010 = pd.concat([df_2010_1, df_2010_2, df_2010_3, df_2010_4, df_2010_5])
df_2010.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1    372
# 1  01  ONE FAMILY HOMES                                            1    372
# 2  02  TWO FAMILY HOMES                                            1    376
# 3  03  THREE FAMILY HOMES                                          1    373
# 4  03  THREE FAMILY HOMES                                          1    393
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   38                                  S1
# 1   38                                  S1
# 2   32                                  S2
# 3   16                                  C0
# 4    9                                  C0
#
# ...

# %%
df_2010.to_csv('data/df_2010.csv')

# %%
df_2011_1 = pd.read_excel('data/NYC_Sales_2003-2020/2011_manhattan.xls', header=4)
df_2011_2 = pd.read_excel('data/NYC_Sales_2003-2020/2011_bronx.xls', header=4)
df_2011_3 = pd.read_excel('data/NYC_Sales_2003-2020/2011_queens.xls', header=4)
df_2011_4 = pd.read_excel('data/NYC_Sales_2003-2020/2011_brooklyn.xls', header=4)
df_2011_5 = pd.read_excel('data/NYC_Sales_2003-2020/2011_statenisland.xls', header=4)

# %%
df_2011_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21500 entries, 0 to 21499
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         21500 non-null  int64
#  1   NEIGHBORHOOD                    21500 non-null  object
#  2   BUILDING CLASS CATEGORY         21500 non-null  object
#  3   TAX CLASS AT PRESENT            21500 non-null  object
#  4   BLOCK                           21500 non-null  int64
#  5   LOT                             21500 non-null  int64
#  6   EASE-MENT                       21500 non-null  object
#  7   BUILDING CLASS AT PRESENT       21500 non-null  object
#  8   ADDRESS                         21500 non-null  object
#  9   APARTMENT NUMBER                21500 non-null  object
#  10  ZIP CODE                        21500 non-null  int64
#  11  RESIDENTIAL UNITS               21500 non-null  int64
# ...

# %%
df_2011 = pd.concat([df_2011_1, df_2011_2, df_2011_3, df_2011_4, df_2011_5])
df_2011.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1    376
# 1  02  TWO FAMILY HOMES                                            1    373
# 2  07  RENTALS - WALKUP APARTMENTS                                2A    372
# 3  07  RENTALS - WALKUP APARTMENTS                                 2    376
# 4  07  RENTALS - WALKUP APARTMENTS                                 2    377
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   43                                  S1
# 1    1                                  S2
# 2   31                                  C3
# 3   54                                  C4
# 4    2                                  C7
#
# ...

# %%
df_2011.to_csv('data/df_2011.csv')

# %%
df_2012_1 = pd.read_excel('data/NYC_Sales_2003-2020/2012_manhattan.xls', header=4)
df_2012_2 = pd.read_excel('data/NYC_Sales_2003-2020/2012_bronx.xls', header=4)
df_2012_3 = pd.read_excel('data/NYC_Sales_2003-2020/2012_queens.xls', header=4)
df_2012_4 = pd.read_excel('data/NYC_Sales_2003-2020/2012_brooklyn.xls', header=4)
df_2012_5 = pd.read_excel('data/NYC_Sales_2003-2020/2012_statenisland.xls', header=4)

# %%
df_2012 = pd.concat([df_2012_1, df_2012_2, df_2012_3, df_2012_4, df_2012_5])
df_2012.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          1  ALPHABET CITY
# 1          1  ALPHABET CITY
# 2          1  ALPHABET CITY
# 3          1  ALPHABET CITY
# 4          1  ALPHABET CITY
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  03  THREE FAMILY HOMES                                            1
# 1  07  RENTALS - WALKUP APARTMENTS                                   2
# 2  07  RENTALS - WALKUP APARTMENTS                                   2
# 3  07  RENTALS - WALKUP APARTMENTS                                  2A
# 4  07  RENTALS - WALKUP APARTMENTS                                   2
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0      377     10                                      C0
# 1      375     62                                      C4
# 2      376     30                                      C4
# 3      377     52                                      C2
# ...

# %%
df_2012.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
df_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84081 entries, 0 to 6230
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         84081 non-null  int64
#  1   NEIGHBORHOOD                    84081 non-null  object
#  2   BUILDING CLASS CATEGORY         84081 non-null  object
#  3   TAX CLASS AT PRESENT            84081 non-null  object
#  4   BLOCK                           84081 non-null  int64
#  5   LOT                             84081 non-null  int64
#  6   EASE-MENT                       84081 non-null  object
#  7   BUILDING CLASS AT PRESENT       84081 non-null  object
#  8   ADDRESS                         84081 non-null  object
#  9   APARTMENT NUMBER                84081 non-null  object
#  10  ZIP CODE                        84081 non-null  int64
#  11  RESIDENTIAL UNITS               84081 non-null  int64
# ...

# %%
df_2012.to_csv('data/df_2012.csv')

# %%
df_2013_1 = pd.read_excel('data/NYC_Sales_2003-2020/2013_manhattan.xls', header=4)
df_2013_2 = pd.read_excel('data/NYC_Sales_2003-2020/2013_bronx.xls', header=4)
df_2013_3 = pd.read_excel('data/NYC_Sales_2003-2020/2013_queens.xls', header=4)
df_2013_4 = pd.read_excel('data/NYC_Sales_2003-2020/2013_brooklyn.xls', header=4)
df_2013_5 = pd.read_excel('data/NYC_Sales_2003-2020/2013_statenisland.xls', header=4)

# %%
df_2013 = pd.concat([df_2013_1, df_2013_2, df_2013_3, df_2013_4, df_2013_5])
df_2013.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          1  ALPHABET CITY
# 1          1  ALPHABET CITY
# 2          1  ALPHABET CITY
# 3          1  ALPHABET CITY
# 4          1  ALPHABET CITY
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  02  TWO FAMILY DWELLINGS                                          1
# 1  03  THREE FAMILY DWELLINGS                                        1
# 2  04  TAX CLASS 1 CONDOS                                           1C
# 3  07  RENTALS - WALKUP APARTMENTS                                  2B
# 4  07  RENTALS - WALKUP APARTMENTS                                  2B
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0      375     41                                      S2
# 1      377     66                                      C0
# 2      399   1102                                      R6
# 3      372      6                                      C4
# ...

# %%
df_2013.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
df_2013.to_csv('data/df_2013.csv')

# %%
df_2014_1 = pd.read_excel('data/NYC_Sales_2003-2020/2014_manhattan.xls', header=4)
df_2014_2 = pd.read_excel('data/NYC_Sales_2003-2020/2014_bronx.xls', header=4)
df_2014_3 = pd.read_excel('data/NYC_Sales_2003-2020/2014_queens.xls', header=4)
df_2014_4 = pd.read_excel('data/NYC_Sales_2003-2020/2014_brooklyn.xls', header=4)
df_2014_5 = pd.read_excel('data/NYC_Sales_2003-2020/2014_statenisland.xls', header=4)

# %%
df_2014 = pd.concat([df_2014_1, df_2014_2, df_2014_3, df_2014_4, df_2014_5])
df_2014.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          1  ALPHABET CITY
# 1          1  ALPHABET CITY
# 2          1  ALPHABET CITY
# 3          1  ALPHABET CITY
# 4          1  ALPHABET CITY
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  02  TWO FAMILY DWELLINGS                                          1
# 2  03  THREE FAMILY DWELLINGS                                        1
# 3  07  RENTALS - WALKUP APARTMENTS                                  2B
# 4  07  RENTALS - WALKUP APARTMENTS                                   2
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0      402     42                                      S1
# 1      372     37                                      S2
# 2      377     66                                      C0
# 3      372     51                                      C7
# ...

# %%
df_2014.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
df_2014.to_csv('data/df_2014.csv')

# %%
df_2015_1 = pd.read_excel('data/NYC_Sales_2003-2020/2015_manhattan.xls', header=4)
df_2015_2 = pd.read_excel('data/NYC_Sales_2003-2020/2015_bronx.xls', header=4)
df_2015_3 = pd.read_excel('data/NYC_Sales_2003-2020/2015_queens.xls', header=4)
df_2015_4 = pd.read_excel('data/NYC_Sales_2003-2020/2015_brooklyn.xls', header=4)
df_2015_5 = pd.read_excel('data/NYC_Sales_2003-2020/2015_statenisland.xls', header=4)

# %%
df_2015 = pd.concat([df_2015_1, df_2015_2, df_2015_3, df_2015_4, df_2015_5])
df_2015.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          1  ALPHABET CITY
# 1          1  ALPHABET CITY
# 2          1  ALPHABET CITY
# 3          1  ALPHABET CITY
# 4          1  ALPHABET CITY
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  03  THREE FAMILY DWELLINGS                                        1
# 2  03  THREE FAMILY DWELLINGS                                        1
# 3  04  TAX CLASS 1 CONDOS                                           1C
# 4  07  RENTALS - WALKUP APARTMENTS                                  2B
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0      400     19                                      A4
# 1      376     24                                      C0
# 2      377     66                                      C0
# 3      399   1101                                      R6
# ...

# %%
df_2015.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91446 entries, 0 to 8004
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         91446 non-null  int64
#  1   NEIGHBORHOOD                    91446 non-null  object
#  2   BUILDING CLASS CATEGORY         91446 non-null  object
#  3   TAX CLASS AT PRESENT            91446 non-null  object
#  4   BLOCK                           91446 non-null  int64
#  5   LOT                             91446 non-null  int64
#  6   EASE-MENT                       91446 non-null  object
#  7   BUILDING CLASS AT PRESENT       91446 non-null  object
#  8   ADDRESS                         91446 non-null  object
#  9   APARTMENT NUMBER                91446 non-null  object
#  10  ZIP CODE                        91446 non-null  int64
#  11  RESIDENTIAL UNITS               91446 non-null  int64
# ...

# %%
df_2015.to_csv('data/df_2015.csv')

# %%
df_2009_15 = pd.concat([df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015])
df_2009_15.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07  RENTALS - WALKUP APARTMENTS                                2B    372
# 1  07  RENTALS - WALKUP APARTMENTS                                2A    377
# 2  07  RENTALS - WALKUP APARTMENTS                                 2    385
# 3  07  RENTALS - WALKUP APARTMENTS                                2B    386
# 4  07  RENTALS - WALKUP APARTMENTS                                 2    400
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   19                                  C7
# 1   53                                  C2
# 2   53                                  C4
# 3   63                                  D7
# 4   53                                  C1
#
# ...

# %%
df_2009_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 571744 entries, 0 to 8004
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   BOROUGH                         571744 non-null  int64
#  1   NEIGHBORHOOD                    571744 non-null  object
#  2   BUILDING CLASS CATEGORY         571744 non-null  object
#  3   TAX CLASS AT PRESENT            571744 non-null  object
#  4   BLOCK                           571744 non-null  int64
#  5   LOT                             571744 non-null  int64
#  6   EASE-MENT                       571744 non-null  object
#  7   BUILDING CLASS AT PRESENT       571744 non-null  object
#  8   ADDRESS                         571744 non-null  object
#  9   APARTMENT NUMBER                571744 non-null  object
#  10  ZIP CODE                        571744 non-null  int64
#  11  RESIDENTIAL UNITS               571744 non-null  int64
# ...

# %%
df_2009_15.shape
# Out:
# (571744, 21)

# %%
df_2009_15.to_csv('data/df_2009_15.csv')

# %% [markdown]
# # 2016 to 2020 NYC Housing Dataset

# %%
df_2016_1 = pd.read_excel('data/NYC_Sales_2003-2020/2016_manhattan.xls', header=4)
df_2016_2 = pd.read_excel('data/NYC_Sales_2003-2020/2016_bronx.xls', header=4)
df_2016_3 = pd.read_excel('data/NYC_Sales_2003-2020/2016_queens.xls', header=4)
df_2016_4 = pd.read_excel('data/NYC_Sales_2003-2020/2016_brooklyn.xls', header=4)
df_2016_5 = pd.read_excel('data/NYC_Sales_2003-2020/2016_statenisland.xls', header=4)

# %%
df_2016 = pd.concat([df_2016_1, df_2016_2, df_2016_3, df_2016_4, df_2016_5])
df_2016.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          1  ALPHABET CITY
# 1          1  ALPHABET CITY
# 2          1  ALPHABET CITY
# 3          1  ALPHABET CITY
# 4          1  ALPHABET CITY
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  03  THREE FAMILY DWELLINGS                                        1
# 1  07  RENTALS - WALKUP APARTMENTS                                   2
# 2  07  RENTALS - WALKUP APARTMENTS                                  2B
# 3  07  RENTALS - WALKUP APARTMENTS                                   2
# 4  07  RENTALS - WALKUP APARTMENTS                                   2
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0      376     24                                      C0
# 1      385      2                                      C7
# 2      389     53                                      C1
# 3      399     26                                      C7
# ...

# %%
df_2016.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89806 entries, 0 to 8628
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         89806 non-null  int64
#  1   NEIGHBORHOOD                    89806 non-null  object
#  2   BUILDING CLASS CATEGORY         89806 non-null  object
#  3   TAX CLASS AT PRESENT            89806 non-null  object
#  4   BLOCK                           89806 non-null  int64
#  5   LOT                             89806 non-null  int64
#  6   EASE-MENT                       89806 non-null  object
#  7   BUILDING CLASS AT PRESENT       89806 non-null  object
#  8   ADDRESS                         89806 non-null  object
#  9   APARTMENT NUMBER                89806 non-null  object
#  10  ZIP CODE                        89806 non-null  int64
#  11  RESIDENTIAL UNITS               89806 non-null  int64
# ...

# %%
df_2016.to_csv('data/df_2016.csv')

# %%
df_2017_1 = pd.read_excel('data/NYC_Sales_2003-2020/2017_manhattan.xls', header=4)
df_2017_2 = pd.read_excel('data/NYC_Sales_2003-2020/2017_bronx.xls', header=4)
df_2017_3 = pd.read_excel('data/NYC_Sales_2003-2020/2017_queens.xls', header=4)
df_2017_4 = pd.read_excel('data/NYC_Sales_2003-2020/2017_brooklyn.xls', header=4)
df_2017_5 = pd.read_excel('data/NYC_Sales_2003-2020/2017_statenisland.xls', header=4)

# %%
df_2017 = pd.concat([df_2017_1, df_2017_2, df_2017_3, df_2017_4, df_2017_5])
df_2017.head()
# Out:
#    BOROUGH\n NEIGHBORHOOD\n                    BUILDING CLASS CATEGORY\n  \
# 0          1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1          1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2          1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3          1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4          1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AS OF FINAL ROLL 17/18  BLOCK\n  LOT\n EASE-MENT\n  \
# 0                                2      375     28
# 1                                2      385     36
# 2                               2A      392      5
# 3                               2A      392      6
# 4                                2      400     61
#
#   BUILDING CLASS AS OF FINAL ROLL 17/18              ADDRESS\n  \
# 0                                    C4    738 EAST 6TH STREET
# 1                                    C7            27 AVENUE C
# 2                                    C2           151 AVENUE B
# ...

# %%
df_2017.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
df_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88660 entries, 0 to 9596
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         88660 non-null  int64
#  1   NEIGHBORHOOD                    88660 non-null  object
#  2   BUILDING CLASS CATEGORY         88660 non-null  object
#  3   TAX CLASS AT PRESENT            88660 non-null  object
#  4   BLOCK                           88660 non-null  int64
#  5   LOT                             88660 non-null  int64
#  6   EASE-MENT                       88660 non-null  object
#  7   BUILDING CLASS AT PRESENT       88660 non-null  object
#  8   ADDRESS                         88660 non-null  object
#  9   APARTMENT NUMBER                88660 non-null  object
#  10  ZIP CODE                        88660 non-null  int64
#  11  RESIDENTIAL UNITS               88660 non-null  int64
# ...

# %%
df_2017.to_csv('data/df_2017.csv')

# %%
dtype={'APARTMENT NUMBER\n': np.int32,
        'ZIP CODE\n': np.int32,
        'RESIDENTIAL UNITS\n': np.int32,
        'COMMERCIAL UNITS\n': np.int32,
        'TOTAL UNITS\n': np.int32,
        'LAND SQUARE FEET\n': np.int32,
        'GROSS SQUARE FEET\n': np.int32,
        'YEAR BUILT\n': np.int32
        }

# %%
df_2018_1 = pd.read_excel('data/NYC_Sales_2003-2020/2018_manhattan.xlsx', header=4)
df_2018_2 = pd.read_excel('data/NYC_Sales_2003-2020/2018_bronx.xlsx', header=4)
df_2018_3 = pd.read_excel('data/NYC_Sales_2003-2020/2018_queens.xlsx', header=4)
df_2018_4 = pd.read_excel('data/NYC_Sales_2003-2020/2018_brooklyn.xlsx', header=4)
df_2018_5 = pd.read_excel('data/NYC_Sales_2003-2020/2018_statenisland.xlsx', header=4)

# %%
df_2018 = pd.concat([df_2018_1, df_2018_2, df_2018_3, df_2018_4, df_2018_5])
df_2018.head()
# Out:
#    BOROUGH\n NEIGHBORHOOD\n BUILDING CLASS CATEGORY\n  \
# 0          1  ALPHABET CITY   01 ONE FAMILY DWELLINGS
# 1          1  ALPHABET CITY   01 ONE FAMILY DWELLINGS
# 2          1  ALPHABET CITY   01 ONE FAMILY DWELLINGS
# 3          1  ALPHABET CITY   02 TWO FAMILY DWELLINGS
# 4          1  ALPHABET CITY   02 TWO FAMILY DWELLINGS
#
#   TAX CLASS AS OF FINAL ROLL 18/19  BLOCK\n  LOT\n  EASE-MENT\n  \
# 0                                1      390     61          NaN
# 1                                1      390     61          NaN
# 2                                1      400     19          NaN
# 3                                1      390     35          NaN
# 4                                1      404      1          NaN
#
#   BUILDING CLASS AS OF FINAL ROLL 18/19            ADDRESS\n  \
# 0                                    A4  189 EAST 7TH STREET
# 1                                    A4  189 EAST 7TH STREET
# 2                                    A4  526 EAST 5TH STREET
# ...

# %%
df_2018.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83782 entries, 0 to 8789
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         83782 non-null  int64
#  1   NEIGHBORHOOD                    83782 non-null  object
#  2   BUILDING CLASS CATEGORY         83782 non-null  object
#  3   TAX CLASS AT PRESENT            83729 non-null  object
#  4   BLOCK                           83782 non-null  int64
#  5   LOT                             83782 non-null  int64
#  6   EASE-MENT                       0 non-null      float64
#  7   BUILDING CLASS AT PRESENT       83729 non-null  object
#  8   ADDRESS                         83782 non-null  object
#  9   APARTMENT NUMBER                18427 non-null  object
#  10  ZIP CODE                        83780 non-null  float64
#  11  RESIDENTIAL UNITS               83729 non-null  float64
# ...

# %%
df_2018.to_csv('data/df_2018.csv')

# %%
df_2019_1 = pd.read_excel('data/NYC_Sales_2003-2020/2019_manhattan.xlsx', header=4)
df_2019_2 = pd.read_excel('data/NYC_Sales_2003-2020/2019_bronx.xlsx', header=4)
df_2019_3 = pd.read_excel('data/NYC_Sales_2003-2020/2019_queens.xlsx', header=4)
df_2019_4 = pd.read_excel('data/NYC_Sales_2003-2020/2019_brooklyn.xlsx', header=4)
df_2019_5 = pd.read_excel('data/NYC_Sales_2003-2020/2019_statenisland.xlsx', header=4)

# %%
df_2019 = pd.concat([df_2019_1, df_2019_2, df_2019_3, df_2019_4, df_2019_5])
df_2019.head()
# Out:
#    BOROUGH\n NEIGHBORHOOD\n  BUILDING CLASS CATEGORY\n  \
# 0          1  ALPHABET CITY    01 ONE FAMILY DWELLINGS
# 1          1  ALPHABET CITY    01 ONE FAMILY DWELLINGS
# 2          1  ALPHABET CITY    02 TWO FAMILY DWELLINGS
# 3          1  ALPHABET CITY  03 THREE FAMILY DWELLINGS
# 4          1  ALPHABET CITY  03 THREE FAMILY DWELLINGS
#
#   TAX CLASS AS OF FINAL ROLL 18/19  BLOCK\n  LOT\n  EASE-MENT\n  \
# 0                                1      376     43          NaN
# 1                                1      390     61          NaN
# 2                                1      404      1          NaN
# 3                                1      377     56          NaN
# 4                                1      393      9          NaN
#
#   BUILDING CLASS AS OF FINAL ROLL 18/19             ADDRESS\n  \
# 0                                    S1   743 EAST 6TH STREET
# 1                                    A4   189 EAST 7TH STREET
# ...

# %%
df_2019.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
df_2019.to_csv('data/df_2019.csv')

# %%
df_2020_1 = pd.read_excel('data/NYC_Sales_2003-2020/2020_manhattan.xlsx', header=6)
df_2020_2 = pd.read_excel('data/NYC_Sales_2003-2020/2020_bronx.xlsx', header=6)
df_2020_3 = pd.read_excel('data/NYC_Sales_2003-2020/2020_queens.xlsx', header=6)
df_2020_4 = pd.read_excel('data/NYC_Sales_2003-2020/2020_brooklyn.xlsx', header=6)
df_2020_5 = pd.read_excel('data/NYC_Sales_2003-2020/2020_staten_island.xlsx', header=6)

# %%
df_2020 = pd.concat([df_2020_1, df_2020_2, df_2020_3, df_2020_4, df_2020_5])
df_2020.head()
# Out:
#    BOROUGH   NEIGHBORHOOD         BUILDING CLASS CATEGORY  \
# 0      NaN            NaN                             NaN
# 1      1.0  ALPHABET CITY         02 TWO FAMILY DWELLINGS
# 2      1.0  ALPHABET CITY       03 THREE FAMILY DWELLINGS
# 3      1.0  ALPHABET CITY       03 THREE FAMILY DWELLINGS
# 4      1.0  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK   LOT  EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                  NaN    NaN   NaN        NaN                       NaN
# 1                    1  377.0  72.0        NaN                        B9
# 2                    1  377.0  66.0        NaN                        C0
# 3                    1  377.0  66.0        NaN                        C0
# 4                   2B  372.0  10.0        NaN                        C7
#
#                ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL\nUNITS  \
# 0                  NaN              NaN       NaN                 NaN
# ...

# %%
df_2020.columns = ['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
       'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
       'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER',
       'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS',
       'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET',
       'YEAR BUILT', 'TAX CLASS AT TIME OF SALE',
       'BUILDING CLASS AT TIME OF SALE', 'SALE PRICE', 'SALE DATE']

# %%
df_2020.to_csv('data/df_2020.csv')

# %%
df_2016_20 = pd.concat([df_2016, df_2017, df_2018, df_2019, df_2020])
df_2016_20.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0      1.0  ALPHABET CITY
# 1      1.0  ALPHABET CITY
# 2      1.0  ALPHABET CITY
# 3      1.0  ALPHABET CITY
# 4      1.0  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  03  THREE FAMILY DWELLINGS                                      1  376.0
# 1  07  RENTALS - WALKUP APARTMENTS                                 2  385.0
# 2  07  RENTALS - WALKUP APARTMENTS                                2B  389.0
# 3  07  RENTALS - WALKUP APARTMENTS                                 2  399.0
# 4  07  RENTALS - WALKUP APARTMENTS                                 2  399.0
#
#     LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0  24.0                                  C0
# 1   2.0                                  C7
# 2  53.0                                  C1
# 3  26.0                                  C7
# 4  39.0                                  C7
#
# ...

# %%
df_2016_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414857 entries, 0 to 7559
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   BOROUGH                         414852 non-null  float64
#  1   NEIGHBORHOOD                    414852 non-null  object
#  2   BUILDING CLASS CATEGORY         414852 non-null  object
#  3   TAX CLASS AT PRESENT            414568 non-null  object
#  4   BLOCK                           414852 non-null  float64
#  5   LOT                             414852 non-null  float64
#  6   EASE-MENT                       178466 non-null  object
#  7   BUILDING CLASS AT PRESENT       414568 non-null  object
#  8   ADDRESS                         414852 non-null  object
#  9   APARTMENT NUMBER                230293 non-null  object
#  10  ZIP CODE                        414825 non-null  float64
#  11  RESIDENTIAL UNITS               384751 non-null  float64
# ...

# %%
df_2016_20.to_csv('data/df_2016_20.csv')

# %% [markdown]
# # 2003-2020 NYC Housing Dataset

# %%
df_2003_08 = pd.read_csv('data/df_2003_08.csv', index_col=0)
df_2003_08.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  02  TWO FAMILY HOMES                                            1    375
# 1  07  RENTALS - WALKUP APARTMENTS                                2A    372
# 2  07  RENTALS - WALKUP APARTMENTS                                2A    372
# 3  07  RENTALS - WALKUP APARTMENTS                                2B    378
# 4  07  RENTALS - WALKUP APARTMENTS                                 2    391
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   32                                  B9
# 1   31                                  C3
# 2   31                                  C3
# 3   33                                  C4
# 4   12                                  C1
#
# ...

# %%
df_2009_15 = pd.read_csv('data/df_2009_15.csv', index_col=0)
df_2009_15.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07  RENTALS - WALKUP APARTMENTS                                2B    372
# 1  07  RENTALS - WALKUP APARTMENTS                                2A    377
# 2  07  RENTALS - WALKUP APARTMENTS                                 2    385
# 3  07  RENTALS - WALKUP APARTMENTS                                2B    386
# 4  07  RENTALS - WALKUP APARTMENTS                                 2    400
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   19                                  C7
# 1   53                                  C2
# 2   53                                  C4
# 3   63                                  D7
# 4   53                                  C1
#
# ...

# %%
df_2016_20 = pd.read_csv('data/df_2016_20.csv', index_col=0)
df_2016_20.head()
# Out:
# /Users/examsherpa/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    BOROUGH               NEIGHBORHOOD  \
# 0      1.0  ALPHABET CITY
# 1      1.0  ALPHABET CITY
# 2      1.0  ALPHABET CITY
# 3      1.0  ALPHABET CITY
# 4      1.0  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  03  THREE FAMILY DWELLINGS                                      1  376.0
# 1  07  RENTALS - WALKUP APARTMENTS                                 2  385.0
# 2  07  RENTALS - WALKUP APARTMENTS                                2B  389.0
# 3  07  RENTALS - WALKUP APARTMENTS                                 2  399.0
# 4  07  RENTALS - WALKUP APARTMENTS                                 2  399.0
#
#     LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# ...

# %%
df = pd.concat([df_2003_08, df_2009_15, df_2016_20])
df.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0      1.0  ALPHABET CITY
# 1      1.0  ALPHABET CITY
# 2      1.0  ALPHABET CITY
# 3      1.0  ALPHABET CITY
# 4      1.0  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  02  TWO FAMILY HOMES                                            1  375.0
# 1  07  RENTALS - WALKUP APARTMENTS                                2A  372.0
# 2  07  RENTALS - WALKUP APARTMENTS                                2A  372.0
# 3  07  RENTALS - WALKUP APARTMENTS                                2B  378.0
# 4  07  RENTALS - WALKUP APARTMENTS                                 2  391.0
#
#     LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0  32.0                                  B9
# 1  31.0                                  C3
# 2  31.0                                  C3
# 3  33.0                                  C4
# 4  12.0                                  C1
#
# ...

# %%
df.to_csv('data/df_2003_20.csv')

# %% [markdown]
# # Testing Dataset

# %%
test_1 = pd.read_excel('data/nyc_sales/rollingsales_manhattan.xlsx', header=4)
test_2 = pd.read_excel('data/nyc_sales/rollingsales_bronx.xlsx', header=4)
test_3 = pd.read_excel('data/nyc_sales/rollingsales_queens.xlsx', header=4)
test_4 = pd.read_excel('data/nyc_sales/rollingsales_brooklyn.xlsx', header=4)
test_5 = pd.read_excel('data/nyc_sales/rollingsales_statenisland.xlsx', header=4)

# %%
test = pd.concat([test_1, test_2, test_3, test_4, test_5])
test.head()
# Out:
#    BOROUGH   NEIGHBORHOOD         BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY         01 ONE FAMILY DWELLINGS
# 1        1  ALPHABET CITY         02 TWO FAMILY DWELLINGS
# 2        1  ALPHABET CITY       03 THREE FAMILY DWELLINGS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT  EASEMENT BUILDING CLASS AT PRESENT  \
# 0                    1    374   46       NaN                        A4
# 1                    1    377   72       NaN                        B9
# 2                    1    377   66       NaN                        C0
# 3                   2B    372   10       NaN                        C7
# 4                   2B    374    1       NaN                        C7
#
#                    ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0      347 EAST 4TH STREET              NaN  ...                1.0
# ...

# %%
test.to_csv('data/test.csv')

# %%
import pandas as pd

# %%
new = pd.read_csv('data/NYC_Citywide_Annualized_Calendar_Sales_Update.csv')
new.head()
# Out:
# /Users/examsherpa/opt/anaconda3/envs/learn-env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   BOROUGH NEIGHBORHOOD BUILDING CLASS CATEGORY TAX CLASS AS OF FINAL ROLL  \
# 0       1      CHELSEA     21 OFFICE BUILDINGS                          4
# 1       1      CHELSEA     21 OFFICE BUILDINGS                          4
# 2       1      CHELSEA     21 OFFICE BUILDINGS                          4
# 3       1      CHELSEA     21 OFFICE BUILDINGS                          4
# 4       1      CHELSEA     21 OFFICE BUILDINGS                          4
#
#    BLOCK  LOT  EASE-MENT BUILDING CLASS AS OF FINAL ROLL  \
# 0    697    5        NaN                              O2
# 1    697   23        NaN                              O6
# 2    700   55        NaN                              O2
# ...

# %%
new.shape
# Out:
# (413743, 29)

# %%
new.BLOCK = new.BLOCK.astype(str)
new.BLOCK.value_counts()
# Out:
# 1006     1335
# 1171     1226
# 16       1128
# 1009     1020
# 5066      907
#          ...
# 15453       1
# 2259        1
# 13302       1
# 10170       1
# 10715       1
# Name: BLOCK, Length: 13318, dtype: int64
